# %% [markdown]
# Tutorial 4

# %%
#Libraries Required
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

# %%
mat = scipy.io.loadmat("./A00008.mat")
ecg = mat.get('val')
plt.plot(ecg[0])

# %%
from rpeakdetectr.rpeakdetect import detect_beats

# %%
sampling_freq= 300 #ITs given in A00008.hea file
R_peak = (detect_beats(ecg[0],sampling_freq))
R_diff = np.diff(R_peak)
plt.stem(R_peak)
# Out:
# c:\Users\Paras\Desktop\DSP_tutorial\rpeakdetectr\rpeakdetect.py:76: RuntimeWarning: divide by zero encountered in log
#   shannon_energy = -square_decg_power*np.log(square_decg_power)
# c:\Users\Paras\Desktop\DSP_tutorial\rpeakdetectr\rpeakdetect.py:76: RuntimeWarning: invalid value encountered in multiply
#   shannon_energy = -square_decg_power*np.log(square_decg_power)
# <StemContainer object of 3 artists>
