# %%
import pandas as pd

# %%
file_name = "C:\\Users\\Paras\\Desktop\\DSP_tutorial\\training2017\\training2017\\Reference_original.csv"
df = pd.read_csv(file_name)
print(df)
# Out:
#      File Name type
# 0       A00001    N
# 1       A00002    N
# 2       A00003    N
# 3       A00004    A
# 4       A00005    O
# ...        ...  ...
# 8523    A08524    N
# 8524    A08525    O
# 8525    A08526    N
# 8526    A08527    N
# 8527    A08528    N
#
# [8528 rows x 2 columns]

# %%
for index, row in df.iterrows():
    file_name = f"{row[0]}.mat"
