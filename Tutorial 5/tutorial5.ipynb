# %%
import sys
import numpy as np
import scipy.signal 
import scipy.ndimage
import scipy.io
import matplotlib.pyplot as plt

# %%
mat_AF = scipy.io.loadmat('A00004.mat')
ecg_AF = mat_AF.get('val')
plt.plot(ecg_AF[0])

# %%
mat_Noise = scipy.io.loadmat('A00022.mat')
ecg_Noise = mat_Noise.get('val')
plt.plot(ecg_Noise[0])

# %%
mat_Normal = scipy.io.loadmat('A00001.mat')
ecg_Normal = mat_Normal.get('val')
plt.plot(ecg_Normal[0])

# %%
mat_Others = scipy.io.loadmat('A00008.mat')
ecg_Others = mat_Others.get('val')
plt.plot(ecg_Others[0])
